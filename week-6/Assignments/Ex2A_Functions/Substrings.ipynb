# %%
## Exercise 2.A Using built-in functions
## Lab 1. Working with names – parsing strings

# %%
test_name = 'John Doe'

# %%
def parse_and_display(name):
  for i in range(len(name)):
    if name[i] == ' ' :
      first = name [:i]
      last = name [i+1:]
      print(f"Full name: {name}")
      print(f"Fist name: {first}")
      print(f"Last name: {last}")

# %%
 parse_and_display(test_name)
# Out:
# Full name: John Doe
# Fist name: John
# Last name: Doe

# %%
test_list = ['Grace Flores', 'JB Oinonen', 'Ken Penn']

# %%
parse_and_display(test_list[0])
parse_and_display(test_list[1])
parse_and_display(test_list[2])
# Out:
# Full name: Grace Flores
# Fist name: Grace
# Last name: Flores
# Full name: JB Oinonen
# Fist name: JB
# Last name: Oinonen
# Full name: Ken Penn
# Fist name: Ken
# Last name: Penn

# %%
parse_and_display('Paola Martinez')
# Out:
# Full name: Paola Martinez
# Fist name: Paola
# Last name: Martinez

# %%
def parse_and_display2(name):
  words = name.split(' ')
  if len (words) == 1:
      print(f"Full name: {name}")
      print(f"Fist name: {words[0]}")
      print(f"Middle name: N/A")
      print(f"Last name: N/A")
  elif len(words) == 2:
      print(f"Full name: {name}")
      print(f"Fist name: {words[0]}")
      print(f"Middle name: N/A")
      print(f"Last name: {words[1]}")
  elif len(words) == 3:
      print(f"Full name: {name}")
      print(f"Fist name: {words[0]}")
      print(f"Middle name: {words[1]}")
      print(f"Last name: {words[2]}")

# %%
parse_and_display2("Lorde")
parse_and_display2("Billie Eilish")
parse_and_display2("Megan Thee Stallion")
# Out:
# Full name: Lorde
# Fist name: Lorde
# Middle name: N/A
# Last name: N/A
# Full name: Billie Eilish
# Fist name: Billie
# Middle name: N/A
# Last name: Eilish
# Full name: Megan Thee Stallion
# Fist name: Megan
# Middle name: Thee
# Last name: Stallion
